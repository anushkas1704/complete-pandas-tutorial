# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##### oop method for creating graphs - this will be useful for complex analytical applications

# %%
a=[10,20,35,40]
b,=plt.plot(a)
print("b's type", type(b))
b.set_color('r')
print(type(plt.plot()))
plt.show()
# Out:
# b's type <class 'matplotlib.lines.Line2D'>
# <class 'list'>

# %% [markdown]
# #### matplotlib.pyplot.figure() function return figure
# 1. when we plot data on a graph the graph will be drwn on the figure
# 2. by default a fugure is drawn , during plotting in mtplotlib

# %%
import matplotlib.pyplot as plt
import numpy 

x = numpy.linspace(0,5,11)
y = x**2
a = numpy.random.randint(50,size=10)
print(a)
b = numpy.random.randint(20,400,size = 15)
print(b)

plt.plot(a)
plt.plot(b)
#plt.plot(a,b)
# Out:
# [45 45 32  0  3 32 39  8 19 33]
# [222 113 111 231  67  35  27 271 102 272 389 183 331 351 227]

# %%
ax=fig.add_axes([0.1,0.1,0.9,0.9])
plt.plot(x,y)

ax.plot()
fig=plt.figure()

# %% [markdown]
# change resolution using parameter dpi(dot per inch)

# %%
plt.figure(dpi=200)
a=5
b=-4
c=-10
x=numpy.linspace(-10,10,num=1000)
y=a*x**3 + b*x + c + b*c**2
plt.grid()
plt.plot(x,y)
plt.show()

# %% [markdown]
# default value for dpi = 100

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(x,y,'g*--')
plt.show()

# %%
fig=plt.figure(figsize=(10,6))
fig1=fig.add_subplot(2,2,1)
fig1.plot([1,2,5,7])
fig2=fig.add_subplot(2,2,2)
fig2.plot([1,2,5,0])
fig3=fig.add_subplot(2,2,3)
fig3.plot([3,2,5,7])
fig4=fig.add_subplot(2,2,4)
fig4.plot([1,2,5,0])
